# %%
import pandas as pd
import time
import calendar
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            Created Date             Closed Date  \
# 0           0  08/10/2018 09:52:07 PM  08/11/2018 06:40:29 AM
# 1           1  09/05/2018 08:15:30 PM  09/10/2018 11:16:49 PM
# 2           2  05/28/2018 04:43:42 PM  05/28/2018 11:48:39 PM
# 3           3  09/06/2018 10:54:28 AM  09/10/2018 11:19:56 PM
# 4           4  05/31/2018 08:54:18 PM  06/01/2018 06:17:03 AM
#
#      Complaint Type                   Descriptor    Location Type  \
# 0   Illegal Parking  Parking Permit Improper Use  Street/Sidewalk
# 1  Derelict Vehicle           With License Plate  Street/Sidewalk
# 2  Derelict Vehicle           With License Plate  Street/Sidewalk
# 3  Derelict Vehicle           With License Plate  Street/Sidewalk
# 4  Derelict Vehicle           With License Plate  Street/Sidewalk
#
#    Incident Zip                Due Date  \
# 0       11102.0  08/11/2018 05:52:07 AM
# 1       10314.0  09/06/2018 04:15:30 AM
# 2       10465.0  05/29/2018 12:43:42 AM
# 3       10314.0  09/06/2018 06:54:28 PM
# 4       10465.0  06/01/2018 04:54:18 AM
#
#                               Resolution Description  \
# 0  The Police Department responded and upon arriv...
# 1  The Police Department responded to the complai...
# 2  The Police Department reviewed your complaint ...
# 3  The Police Department responded to the complai...
# 4  The Police Department reviewed your complaint ...
#
#   Resolution Action Updated Date   Latitude  Longitude        Borough  \
# 0         08/11/2018 06:40:29 AM  40.773905 -73.929708         QUEENS
# 1         09/10/2018 11:16:49 PM  40.604711 -74.125725  STATEN ISLAND
# 2         05/28/2018 11:47:35 PM  40.826894 -73.827604          BRONX
# 3         09/10/2018 11:19:56 PM  40.609554 -74.156016  STATEN ISLAND
# 4         06/01/2018 06:16:50 AM  40.842282 -73.824550          BRONX
#
#             City       Complaint Subgroups  Distance To Closest Station
# 0        ASTORIA           Traffic related                   748.852906
# 1  STATEN ISLAND  Street condition related                  1528.627451
# 2          BRONX  Street condition related                  1222.648629
# 3  STATEN ISLAND  Street condition related                  2748.281906
# 4          BRONX  Street condition related                  1632.063742

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'], format = '%m/%d/%Y %H:%M:%S %p')
df['Closed Date'] = pd.to_datetime(df['Closed Date'], format = '%m/%d/%Y %H:%M:%S %p')
df['Incident Zip'] = df['Incident Zip'].astype(int)

def to_hours(td):
    return round(td.seconds/float(3600),1)

df['Efficiency'] = (df['Closed Date'] - df['Created Date']).apply(lambda x: to_hours(x))
df['Month'] = df['Created Date'].apply(lambda x: calendar.month_name[x.month])

# %%
df_alt = df.copy()

# %%
df_alt = df_alt[(df_alt['Incident Zip'] >= 10000) & (df_alt['Incident Zip'] <= 11697)]

# %%
df_d3 = df_alt.groupby(['Incident Zip'])['Efficiency'].mean().reset_index()

# %%
df_d3.to_csv("nyc_efficiency.csv")
